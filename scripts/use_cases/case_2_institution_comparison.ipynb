# %% [markdown]
# # Case 2: Institutional Comparison
#
# In this practical case, we will consult the acts published in a specific year (for example, 2025) and group the number of acts issued by each institution (Commission, Council, European Parliament, etc.).

# %%
from bulletin.eurlex.api.client import EurlexBulletinClient

client = EurlexBulletinClient()

date_start = "2025-01-01"
date_end = "2025-12-31"

print(f"Downloading acts from {date_start} to {date_end}...")
acts_df = client.get_acts(date=date_start, date_end=date_end, language="ENG", output_format="df")
# Out:
# Downloading acts from 2025-01-01 to 2025-12-31...

# %% [markdown]
# ### Graphical representation of the number of acts issued by institution

# %%
# %pip install matplotlib seaborn
import matplotlib.pyplot as plt
import seaborn as sns

institution_counts = acts_df['institution_label'].value_counts().nlargest(15).reset_index()
institution_counts.columns = ['institution_label', 'count']

institution_counts = institution_counts.sort_values('count', ascending=False)
plt.figure(figsize=(10, 12))
ax = sns.barplot(data=institution_counts, y='institution_label', x='count', palette='Blues_d')

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f"{int(width)}", xy=(width, p.get_y() + p.get_height() / 2), xytext=(5, 0), textcoords='offset points', ha='left', va='center')
plt.title('Number of acts issued by institution (top 20, 2025)')
plt.xlabel('Number of acts')
plt.ylabel('Institution')
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: matplotlib in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: tzdata in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Usuario\Desktop\bulletin-fetcher\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_51584\2808643314.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=institution_counts, y='institution_label', x='count', palette='Blues_d')
